# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
matches_data = pd.read_csv('WorldCupMatches.csv')
matches_data
# Out:
#         Year              Datetime    Stage         Stadium         City  \
# 0     1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1     1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2     1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3     1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4     1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# ...      ...                   ...      ...             ...          ...
# 4567     NaN                   NaN      NaN             NaN          NaN
# 4568     NaN                   NaN      NaN             NaN          NaN
# 4569     NaN                   NaN      NaN             NaN          NaN
# 4570     NaN                   NaN      NaN             NaN          NaN
# 4571     NaN                   NaN      NaN             NaN          NaN
#
#      Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# ...

# %%
players_data = pd.read_csv('WorldCupPlayers.csv')
players_data.head()
# Out:
#    RoundID  MatchID Team Initials           Coach Name Line-up  Shirt Number  \
# 0      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 1      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 2      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 3      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 4      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
#
#         Player Name Position Event
# 0       Alex THEPOT       GK   NaN
# 1   Oscar BONFIGLIO       GK   NaN
# 2  Marcel LANGILLER      NaN  G40'
# 3      Juan CARRENO      NaN  G70'
# 4   Ernest LIBERATI      NaN   NaN

# %%
tournaments_data = pd.read_csv('WorldCups.csv')
tournaments_data.head()
# Out:
#    Year      Country      Winner      Runners-Up    Third      Fourth  \
# 0  1930      Uruguay     Uruguay       Argentina      USA  Yugoslavia
# 1  1934        Italy       Italy  Czechoslovakia  Germany     Austria
# 2  1938       France       Italy         Hungary   Brazil      Sweden
# 3  1950       Brazil     Uruguay          Brazil   Sweden       Spain
# 4  1954  Switzerland  Germany FR         Hungary  Austria     Uruguay
#
#    GoalsScored  QualifiedTeams  MatchesPlayed Attendance
# 0           70              13             18    590.549
# 1           70              16             17    363.000
# 2           84              15             18    375.700
# 3           88              13             22  1.045.246
# 4          140              16             26    768.607

# %%
matches_data['Home Team Name'].value_counts()
# Out:
# Brazil                        82
# Italy                         57
# Argentina                     54
# Germany FR                    43
# England                       35
#                               ..
# Wales                          1
# Norway                         1
# rn">United Arab Emirates       1
# Haiti                          1
# rn">Bosnia and Herzegovina     1
# Name: Home Team Name, Length: 78, dtype: int64

# %%
matches_data.dropna(subset=['Year'], inplace=True)

# %%
a = matches_data[matches_data['Home Team Name'].str.contains('rn">')]['Home Team Name'].value_counts()

# %%
a
# Out:
# rn">Republic of Ireland       5
# rn">United Arab Emirates      1
# rn">Trinidad and Tobago       1
# rn">Serbia and Montenegro     1
# rn">Bosnia and Herzegovina    1
# Name: Home Team Name, dtype: int64

# %%
b = list(a.index)

# %%
c = []
for i in b:
    c.append(i.split('>')[1])
c
# Out:
# ['Republic of Ireland',
#  'United Arab Emirates',
#  'Trinidad and Tobago',
#  'Serbia and Montenegro',
#  'Bosnia and Herzegovina']

# %%
d = ['Germany FR', 'Maracan� - Est�dio Jornalista M�rio Filho', 'Estadio do Maracana']
e = ['Germany', 'Maracan Stadium', 'Maracan Stadium']

# %%
correct = c + e
correct
# Out:
# ['Republic of Ireland',
#  'United Arab Emirates',
#  'Trinidad and Tobago',
#  'Serbia and Montenegro',
#  'Bosnia and Herzegovina',
#  'Germany',
#  'Maracan Stadium',
#  'Maracan Stadium']

# %%
wrong = b + d
wrong
# Out:
# ['rn">Republic of Ireland',
#  'rn">United Arab Emirates',
#  'rn">Trinidad and Tobago',
#  'rn">Serbia and Montenegro',
#  'rn">Bosnia and Herzegovina',
#  'Germany FR',
#  'Maracan� - Est�dio Jornalista M�rio Filho',
#  'Estadio do Maracana']

# %%
tournaments_data.replace(to_replace='Germany FR', value='Germany', inplace=True)

# %%
matches_data.replace(to_replace=wrong, value=correct, inplace=True)

# %%
players_data.replace(to_replace=wrong, value=correct, inplace=True)

# %%
matches_data[matches_data['Home Team Name'].str.contains('rn">')]['Home Team Name'].value_counts()
# Out:
# Series([], Name: Home Team Name, dtype: int64)
